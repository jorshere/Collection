# %%
import requests;
from bs4 import BeautifulSoup

# %%
r = requests.get("https://www.99acres.com/search/property/buy/pune?city=19&preference=S&area_unit=1&budget_min=0&res_com=R")

c = r.content

# %%
soup = BeautifulSoup(c,"html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="" data-iswebp="false" data-reactroot="" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://static.99acres.com" rel="preconnect dns-prefetch"/>
#   <link href="https://mediacdn.99acres.com" rel="preconnect dns-prefetch"/>
#   <link href="https://fonts.gstatic.com" rel="preconnect dns-prefetch"/>
#   <link id="__tealBannerCss__" rel="stylesheet" type="text/css"/>
#   <link id="__recomCss__" rel="stylesheet" type="text/css"/>
#   <link id="__topDealerCss__" rel="stylesheet" type="text/css"/>
#   <script data-react-helmet="true" type="application/ld+json">
# ...

# %%
all = soup.find_all("table",{"class":"false"})

# all[0].find("h2",{"class":"heading-6 flex items-center font-semi-bold m-0"}).text

all
# Out:
# [<table class="false"><tr><td class="srpTuple__tdClassPremium" colspan="3"><a class="body_med srpTuple__propertyName" href="/2-bhk-bedroom-apartment-flat-for-sale-in-kumar-palmcrest-pisoli-pune-766-sq-ft-to-779-sq-ft-npspid-R59274380" id="srp_tuple_property_title" target="blank"><h2>2 BHK Apartment in Pisoli</h2></a></td></tr><tr><td class="srpTuple__propertyPremiumHeading srpTuple__spacer10 srpTuple__tdClasstwoPremium" colspan="3" id="srp_tuple_society_heading"><a class="srpTuple__dFlex" href="/kumar-palmcrest-pisoli-pune-npxid-r1183" target="blank">Kumar Palmcrest</a></td></tr><tr><td><div class="srpTuple__premiumContainer"><div><div class="commonSlider__SliderWrap"><div class="SliderTagsAndChips__container"><div class="SliderTagsAndChips__places SliderTagsAndChips__qsPrevWidth"><div class="SliderTagsAndChips__icon"><i class="iconS_poi_16 icon_rlgs"></i></div><div class="SliderTagsAndChips__nearByInfo"><div class="SliderTagsAndChips__tagCount">15</div><div class="SliderTagsAndChips
# ...

# %%
for item in all:
    d={}
    
    d["Description"] = item.find("td",{"class":"srpTuple__tdClassPremium"}).text
#     print(d["Description"])

    
    d["Name"] = item.find("td",{"class":"srpTuple__propertyPremiumHeading srpTuple__spacer10 srpTuple__tdClasstwoPremium"}).text
    print(d["Name"])
# Out:
# Kumar Palmcrest
# Ranjai Apartments
# Ganga New Town3.5 ★
# Vivaan Park
# Kanha Vrundavan Heritage
# Kanha Vrundavan Heritage
# Vivaan Park
# Ganga New Town3.5 ★
# Dreamland Allure
# Purva Emerald Bay
# Purva Aspire
# Purva Aspire
# JK Realty Dhruvaa
# SK Shreeyog
# Ganraj Skydale
# Ganraj Skydale
# Ganga Serio
# Anshul Kanvas
# Malpani Green Park
# Malpani Green Park
# Platinum Glory
# Purva Silversands
# Purva Emerald Bay
# Purva Silversands
